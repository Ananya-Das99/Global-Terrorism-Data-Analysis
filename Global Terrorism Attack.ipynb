# %% [markdown]
# # GLOBAL TERRORISM DATA ANALYSIS

# %% [markdown]
# ![96670ti1.jpg](attachment:96670ti1.jpg)

# %% [markdown]
# NAME- ANANYA DAS

# %% [markdown]
# The Sparks foundation

# %% [markdown]
# BATCH-GRIP-NOVEMBER 2023

# %%
import pandas as pd
pd.options.mode.chained_assignment = None  # default='warn'
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import plotly.express as px

# %%
data = pd.read_csv("C:/Users/dasan/OneDrive/Desktop/gtd.csv",encoding = 'latin - 1',low_memory = False)

# %%
data.head(10)
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  1.970000e+11   1970       7     2        NaN         0        NaN       58
# 1  1.970000e+11   1970       0     0        NaN         0        NaN      130
# 2  1.970010e+11   1970       1     0        NaN         0        NaN      160
# 3  1.970010e+11   1970       1     0        NaN         0        NaN       78
# 4  1.970010e+11   1970       1     0        NaN         0        NaN      101
# 5  1.970010e+11   1970       1     1        NaN         0        NaN      217
# 6  1.970010e+11   1970       1     2        NaN         0        NaN      218
# 7  1.970010e+11   1970       1     2        NaN         0        NaN      217
# 8  1.970010e+11   1970       1     2        NaN         0        NaN      217
# 9  1.970010e+11   1970       1     3        NaN         0        NaN      217
#
#           country_txt  region  ...  \
# 0  Dominican Republic       2  ...
# 1              Mexico       1  ...
# ...

# %%
data.shape
# Out:
# (181691, 135)

# %%
data.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
data.info
# Out:
# <bound method DataFrame.info of              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0       1.970000e+11   1970       7     2        NaN         0        NaN
# 1       1.970000e+11   1970       0     0        NaN         0        NaN
# 2       1.970010e+11   1970       1     0        NaN         0        NaN
# 3       1.970010e+11   1970       1     0        NaN         0        NaN
# 4       1.970010e+11   1970       1     0        NaN         0        NaN
# ...              ...    ...     ...   ...        ...       ...        ...
# 181686  2.017120e+11   2017      12    31        NaN         0        NaN
# 181687  2.017120e+11   2017      12    31        NaN         0        NaN
# 181688  2.017120e+11   2017      12    31        NaN         0        NaN
# 181689  2.017120e+11   2017      12    31        NaN         0        NaN
# 181690  2.017120e+11   2017      12    31        NaN         0        NaN
#
# ...

# %%
data.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002704e+11    2002.638997       6.467277      15.505644
# std    1.325955e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991020e+11    1991.000000       4.000000       8.000000
# 50%    2.009020e+11    2009.000000       6.000000      15.000000
# 75%    2.014080e+11    2014.000000       9.000000      23.000000
# max    2.017120e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %%
pd.set_option('display.max_rows',1000);
data.nunique()
# Out:
# eventid                  576
# iyear                     47
# imonth                    13
# iday                      32
# approxdate              2244
# extended                   2
# resolution              1859
# country                  205
# country_txt              205
# region                    12
# region_txt                12
# provstate               2855
# city                   36674
# latitude               48322
# longitude              48039
# specificity                5
# vicinity                   3
# location               44109
# summary               112492
# crit1                      2
# crit2                      2
# crit3                      2
# doubtterr                  3
# alternative                5
# alternative_txt            5
# multiple                   2
# success                    2
# suicide                    2
# attacktype1                9
# attacktype1_txt            9
# attacktype2                9
# attacktype2_txt            9
# ...

# %% [markdown]
# cleaning the data

# %%
data.rename(columns={'iyear':'Year','imonth':'Month','iday':'Day','country_txt':'Country','region_txt':'Region',
                             'provstate':'State','city':'City','attacktype1_txt':'Attack_type','targtype1_txt':'Target_type',
                             'targsubtype1_txt':'Target_subtype','gname':'Gang_name','weaptype1_txt':'Weapon_type'},inplace=True)

# %%
data
# Out:
#              eventid  Year  Month  Day approxdate  extended resolution  \
# 0       1.970000e+11  1970      7    2        NaN         0        NaN
# 1       1.970000e+11  1970      0    0        NaN         0        NaN
# 2       1.970010e+11  1970      1    0        NaN         0        NaN
# 3       1.970010e+11  1970      1    0        NaN         0        NaN
# 4       1.970010e+11  1970      1    0        NaN         0        NaN
# ...              ...   ...    ...  ...        ...       ...        ...
# 181686  2.017120e+11  2017     12   31        NaN         0        NaN
# 181687  2.017120e+11  2017     12   31        NaN         0        NaN
# 181688  2.017120e+11  2017     12   31        NaN         0        NaN
# 181689  2.017120e+11  2017     12   31        NaN         0        NaN
# 181690  2.017120e+11  2017     12   31        NaN         0        NaN
#
#         country             Country  region  ... addnotes  \
# ...

# %%
terrorism_df=data[['Year','Month','Day','Country','Region','State','City','Attack_type','Target_type','Target_subtype','Gang_name','Weapon_type']]

# %%
terrorism_df.isnull().sum()
# Out:
# Year                  0
# Month                 0
# Day                   0
# Country               0
# Region                0
# State               421
# City                434
# Attack_type           0
# Target_type           0
# Target_subtype    10373
# Gang_name             0
# Weapon_type           0
# dtype: int64

# %%
terrorism_df['State'].fillna(0,inplace=True)
terrorism_df['City'].fillna(0,inplace=True)
terrorism_df['Target_subtype'].fillna(0,inplace=True)

# %%
terrorism_df.isnull().sum()
# Out:
# Year              0
# Month             0
# Day               0
# Country           0
# Region            0
# State             0
# City              0
# Attack_type       0
# Target_type       0
# Target_subtype    0
# Gang_name         0
# Weapon_type       0
# dtype: int64

# %% [markdown]
# Great! No more null data is present

# %%
terrorism_df.describe()
# Out:
#                 Year          Month            Day
# count  181691.000000  181691.000000  181691.000000
# mean     2002.638997       6.467277      15.505644
# std        13.259430       3.388303       8.814045
# min      1970.000000       0.000000       0.000000
# 25%      1991.000000       4.000000       8.000000
# 50%      2009.000000       6.000000      15.000000
# 75%      2014.000000       9.000000      23.000000
# max      2017.000000      12.000000      31.000000

# %%
terrorism_df['Country'].value_counts().head(10)
# Out:
# Iraq              24636
# Pakistan          14368
# Afghanistan       12731
# India             11960
# Colombia           8306
# Philippines        6908
# Peru               6096
# El Salvador        5320
# United Kingdom     5235
# Turkey             4292
# Name: Country, dtype: int64

# %%
terrorism_df['Region'].value_counts().head(10) # top 10 affected regions
# Out:
# Middle East & North Africa     50474
# South Asia                     44974
# South America                  18978
# Sub-Saharan Africa             17550
# Western Europe                 16639
# Southeast Asia                 12485
# Central America & Caribbean    10344
# Eastern Europe                  5144
# North America                   3456
# East Asia                        802
# Name: Region, dtype: int64

# %%
terrorism_df['State'].value_counts().head(10) #top 10 affected states
# Out:
# Baghdad               7645
# Northern Ireland      4498
# Unknown               4290
# Balochistan           3710
# Saladin               3411
# Al Anbar              3299
# Nineveh               3241
# Sindh                 3206
# Khyber Pakhtunkhwa    3084
# Diyala                3041
# Name: State, dtype: int64

# %%
terrorism_df['City'].value_counts().head(10) # top 10 affected city
# Out:
# Unknown         9775
# Baghdad         7589
# Karachi         2652
# Lima            2359
# Mosul           2265
# Belfast         2171
# Santiago        1621
# Mogadishu       1581
# San Salvador    1558
# Istanbul        1048
# Name: City, dtype: int64

# %%
terrorism_df['Target_subtype'].value_counts().head(10)
# Out:
# Unnamed Civilian/Unspecified                               11596
# Police Security Forces/Officers                            11178
# 0                                                          10373
# Military Unit/Patrol/Convoy                                 8277
# Military Personnel (soldiers, troops, officers, forces)     7963
# Government Personnel (excluding police, military)           6610
# Village/City/Town/Suburb                                    6542
# Politician or Political Party Movement/Meeting/Rally        6306
# Police Building (headquarters, station, school)             5907
# Military Barracks/Base/Headquarters/Checkpost               5211
# Name: Target_subtype, dtype: int64

# %%
terrorism_df['Attack_type'].value_counts().head(10)
# Out:
# Bombing/Explosion                      88255
# Armed Assault                          42669
# Assassination                          19312
# Hostage Taking (Kidnapping)            11158
# Facility/Infrastructure Attack         10356
# Unknown                                 7276
# Unarmed Assault                         1015
# Hostage Taking (Barricade Incident)      991
# Hijacking                                659
# Name: Attack_type, dtype: int64

# %%
terrorism_df['Gang_name'].value_counts().head(10)
# Out:
# Unknown                                             82782
# Taliban                                              7478
# Islamic State of Iraq and the Levant (ISIL)          5613
# Shining Path (SL)                                    4555
# Farabundo Marti National Liberation Front (FMLN)     3351
# Al-Shabaab                                           3288
# New People's Army (NPA)                              2772
# Irish Republican Army (IRA)                          2671
# Revolutionary Armed Forces of Colombia (FARC)        2487
# Boko Haram                                           2418
# Name: Gang_name, dtype: int64

# %%
terrorism_df['Weapon_type'].value_counts().head(10)

#These are the most chosen weapons for attacks.
# Out:
# Explosives                                                                     92426
# Firearms                                                                       58524
# Unknown                                                                        15157
# Incendiary                                                                     11135
# Melee                                                                           3655
# Chemical                                                                         321
# Sabotage Equipment                                                               141
# Vehicle (not to include vehicle-borne explosives, i.e., car or truck bombs)      136
# Other                                                                            114
# Biological                                                                        35
# Name: Weapon_type, dtype: int64

# %% [markdown]
# ## VISUALIZATION

# %% [markdown]
#  let us find some hot zones using visualizations. For this, we have to use matplotlib and seaborn which we have installed at the beginning.

# %%
plt.figure(figsize=(20,5));
sns.countplot(x=terrorism_df.Weapon_type)
# Out:
# <AxesSubplot:xlabel='Weapon_type', ylabel='count'>

# %% [markdown]
# Most of the attacks were attacked through explosives and then through firearms.

# %%
plt.figure(figsize=(27,5))
plt.title('Attacks by Year')
sns.countplot(x=terrorism_df.Year)
# Out:
# <AxesSubplot:title={'center':'Attacks by Year'}, xlabel='Year', ylabel='count'>

# %% [markdown]
# Attacks were more during 2014 and then in 2015. When compared to attacks from 1970 onwards, the last 6 years scored a maximum. But from 2014 onwards count started decreasing.

# %%
plt.figure(figsize=(20,5))
plt.title('Attacks by Month')
sns.countplot(x=terrorism_df.Month)
# Out:
# <AxesSubplot:title={'center':'Attacks by Month'}, xlabel='Month', ylabel='count'>

# %% [markdown]
# Almost every month has the same contribution

# %%
fig,axes = plt.subplots(figsize=(30,11),nrows=1,ncols=2)
sns.barplot(x = data['Country'].value_counts()[:20].values, y = data['Country'].value_counts()[:20].index, 
            ax=axes[0],palette = 'coolwarm_r');
sns.barplot(x = data['Region'].value_counts()[:20].values, y = data['Region'].value_counts()[:20].index, 
            ax=axes[1],palette = 'coolwarm_r');

# %%
plt.figure(figsize=(20,5));
plt.rcParams.update({'font.size':10});
plt.xticks(rotation = 90)
plt.title('Based on Target type')
sns.countplot(x=terrorism_df.Target_type);

# %%
plt.figure(figsize=(20,5));
plt.rcParams.update({'font.size':10});
plt.xticks(rotation = 90)
plt.title('Based on Attack type')
sns.countplot(x=terrorism_df.Attack_type);

# %%
plt.subplots(figsize=(20,10))
plt.title('Most Acive Terrorist Organizations')
sns.barplot(x = data['Gang_name'].value_counts()[1:20].values, y = data['Gang_name'].value_counts()[1:20].index, palette = 'coolwarm_r');

# %% [markdown]
# ## Insights Found

# %% [markdown]
# Number of attacks have increased from 1970 to 2017 by 94.0%.

# %% [markdown]
# The Middle East & North Africa leads 1st among all the regions and then South Asia takes 2nd place.

# %% [markdown]
# For most of the attacks, the target is Private Citizens& property and the next Military leads.

# %% [markdown]
# Most of the attacks were through either Bombing or Explosion.

# %% [markdown]
# Country Iraq is found to be highly targetted and has the most attacks and hence is considered as the hot zone of terrorism.
